# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from arch import arch_model
from scipy.stats import rankdata
from scipy.stats import t
import pyvinecopulib as pv
from scipy.stats import kendalltau
import networkx as nx
from scipy.optimize import minimize
import scipy.stats as stats
import statsmodels.api as sm

# %%
df = pd.read_excel("Data_FF.xlsx", header=[0], index_col=0)
returns = df
log_returns = np.log1p(returns / 100)

# %%
def orthogonalize(target, others):
    data = log_returns[[target] + others].dropna()  # Drop rows with NaNs only in relevant columns
    X = data[others]
    y = data[target]
    model = LinearRegression().fit(X, y)
    residuals = pd.Series(y - model.predict(X), index=X.index)
    return residuals

pure_returns = pd.DataFrame(index=log_returns.index)

for target in log_returns.columns:
    others = [col for col in log_returns.columns if col != target]
    pure_returns[target + "_pure"] = orthogonalize(target, others)

# pure_returns    #this is now uncorrelated time series with the other variables

# %%
pure_returns_rescaled = pd.DataFrame(index=pure_returns.index)

for col in pure_returns.columns:
    original_col = col.replace("_pure", "")
    orig_mean = log_returns[original_col].mean()
    orig_std = log_returns[original_col].std()
    pure_std = pure_returns[col].std()
    
    if pure_std != 0:
        pure_returns_rescaled[col] = pure_returns[col] * (orig_std / pure_std) + orig_mean
    else:
        pure_returns_rescaled[col] = pure_returns[col]

# %%
factor_groups = {
    "Mkt-RF": ["Mkt-RF"],
    "SMB": ["SMB"],
    "HML": ["HML"],
    "RMW": ["RMW"],
    "CMA": ["CMA"],
    "RF": ["RF"]
}

corr = pure_returns.corr()
pair_corrs = []

columns = corr.columns.tolist()
n = len(columns)

for i in range(n):
    for j in range(i + 1, n):  # only upper triangle, avoids duplicates and self-pairs
        pair_corrs.append(corr.iloc[i, j])

avg_corr = np.mean(pair_corrs)
print("Avg correlation across all factor pairs:", avg_corr)
# Out:
# Avg correlation across all factor pairs: 0.014672957590315321

# %%
pseudo_obs = pd.DataFrame(index=pure_returns.index)

for col in pure_returns.columns:
    series = pure_returns[col].dropna() * 10000
    if len(series) < 250:
        continue

    try:
        model = arch_model(series, vol='Garch', p=1, q=1, dist='StudentsT')
        res = model.fit(disp='off')

        # Get standardized residuals
        std_resid = res.std_resid

        # Get degrees of freedom
        nu = res.params["nu"]

        # Apply t-CDF to get PIT-uniforms
        u_t = pd.Series(t.cdf(std_resid, df=nu), index=std_resid.index)

        # Store in DataFrame
        pseudo_obs[col] = u_t

    except Exception as e:
        print(f"GARCH failed on {col}: {e}")

# %%
# ── 1) Prepare your U-matrix ──
# Drop any rows with NaNs, clip to (ε,1−ε), ensure Fortran order
U = pseudo_obs.dropna().to_numpy(dtype=np.float64)
U = np.clip(U, 1e-6, 1 - 1e-6)
U = np.asfortranarray(U)

# ── 2) Set up vine‐level fit controls ──
vine_ctrl = pv.FitControlsVinecop(
    family_set=[
        pv.BicopFamily.indep,
        pv.BicopFamily.gaussian,
        pv.BicopFamily.student,
        pv.BicopFamily.clayton,
        pv.BicopFamily.gumbel,
        pv.BicopFamily.frank
    ],
    parametric_method='itau',       # initialize via Kendall’s τ inversion
    selection_criterion='bic'       # BIC to choose both structure & families
)

# ── 3) Fit the R-vine from data ──
vine = pv.Vinecop.from_data(data=U, controls=vine_ctrl)  # factory method :contentReference[oaicite:0]{index=0}

# %%
# Assume `pure_returns`, `pseudo_obs`, and `vine` are already defined from the user's session
# Align and clean data
common_index = pseudo_obs.dropna().index.intersection(pure_returns.dropna().index)
pure_returns_clean = pure_returns.loc[common_index]
pseudo_obs_clean = pseudo_obs.loc[common_index]

# Step 1: Build sorted marginal return arrays for inverse CDF mapping
sorted_returns = {col: np.sort(pure_returns_clean[col].values) for col in pure_returns_clean.columns}

def inverse_empirical(u, sorted_vals):
    n = len(sorted_vals)
    ranks = u * (n - 1)
    lower_idx = np.floor(ranks).astype(int)
    upper_idx = np.ceil(ranks).astype(int)
    weights = ranks - lower_idx
    return (1 - weights) * sorted_vals[lower_idx] + weights * sorted_vals[upper_idx]

# Step 2: Simulate from vine copula
N = 100000
U_sim = vine.simulate(n=N)
U_sim = np.clip(U_sim, 1e-6, 1 - 1e-6)

# Step 3: Invert to real returns
columns = pseudo_obs_clean.columns
R_sim = np.column_stack([
    inverse_empirical(U_sim[:, i], sorted_returns[col])
    for i, col in enumerate(columns)
])

# Step 4: Create weight vector (equal-weighted portfolio)
beta = np.ones(len(columns)) / len(columns)
P_sim = R_sim @ beta

# Step 5: Compute portfolio performance stats
expected_return = np.mean(P_sim)
volatility = np.std(P_sim)
sharpe_ratio = expected_return / volatility
alpha = 0.95
VaR_alpha = np.quantile(P_sim, 1 - alpha)
ES_alpha = P_sim[P_sim <= VaR_alpha].mean()

# Display portfolio statistics
portfolio_stats = {
    "Expected Return": expected_return,
    "Volatility": volatility,
    "Sharpe Ratio": sharpe_ratio,
    f"VaR {int(alpha*100)}%": VaR_alpha,
    f"ES {int(alpha*100)}%": ES_alpha
}

portfolio_stats
# Out:
# {'Expected Return': np.float64(5.427007200535822e-06),
#  'Volatility': np.float64(0.002124114350098785),
#  'Sharpe Ratio': np.float64(0.0025549505845970256),
#  'VaR 95%': np.float64(-0.003225820436515316),
#  'ES 95%': np.float64(-0.004998607139549403)}

# %%
# Inputs: already simulated
# R_sim: shape (N, d)
# P_sim: shape (N,)
# beta: shape (d,)
# alpha: confidence level (e.g., 0.95)

alpha = 0.95

# Step 1: Compute indicator mask for tail losses
VaR_alpha = np.quantile(P_sim, 1 - alpha)
tail_mask = P_sim <= VaR_alpha

# Step 2: Get individual factor contributions to loss
L_sim = -R_sim * beta  # shape (N, d)
L_tail = L_sim[tail_mask, :]  # shape (~(1-alpha)*N, d)

# Step 3: Compute marginal ES contributions (expected loss in tail per factor)
ES_i = L_tail.mean(axis=0)  # shape (d,)
ES_total = ES_i.sum()

# Step 4: Create results table
columns = pseudo_obs_clean.columns
es_df = pd.DataFrame({
    "Weight (β)": beta,
    "ES Contribution": ES_i,
    "ES %": ES_i / ES_total * 100
}, index=columns)

es_df.loc["Total"] = ["", ES_total, 100.0]
import matplotlib.pyplot as plt

es_df[:-1]["ES %"].plot(kind="bar", figsize=(12, 5), title="ES Contribution by Factor")
plt.ylabel("Percent of ES (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
es_df
# Out:
#             Weight (β)  ES Contribution        ES %
# Mkt-RF_pure   0.166667     3.219387e-03   64.405683
# SMB_pure      0.166667     9.262874e-04   18.530911
# HML_pure      0.166667    -2.144634e-04   -4.290463
# RMW_pure      0.166667     7.118739e-04   14.241446
# CMA_pure      0.166667     3.550706e-04    7.103391
# RF_pure       0.166667     4.515098e-07    0.009033
# Total                      4.998607e-03  100.000000

# %%
# Assumed inputs
# - vine: fitted pyvinecopulib.Vinecop object
# - pseudo_obs_clean: DataFrame of PIT-uniforms (shape T × d)
# - pure_returns_clean: DataFrame of real log returns (same columns as pseudo_obs_clean)
# - sorted_returns: {column_name: np.sort(series)} dict used for inverse_empirical()
# - inverse_empirical(u, sorted_vals): function defined earlier
# - P_sim: previously simulated unconditional portfolio returns
# - beta: portfolio weight vector (shape d,)
# - alpha: confidence level (e.g., 0.95)

# === CONFIGURATION ===
cond_factor = "HML_pure"
u_cond_val = 0.05        # Conditioning on 5th percentile
bandwidth = 0.005        # Width around u_cond_val for filtering
n_samples = 100_000      # Total samples to draw from vine copula
alpha = 0.95             # Risk level for VaR / ES

# === Step 1: Simulate unconditional copula samples ===
U_all = vine.simulate(n_samples)

# === Step 2: Locate conditioning column ===
cond_col = list(pseudo_obs_clean.columns).index(cond_factor)

# === Step 3: Filter samples where conditioned factor ≈ 5th percentile ===
mask = (U_all[:, cond_col] >= u_cond_val - bandwidth) & (U_all[:, cond_col] <= u_cond_val + bandwidth)
U_cond = U_all[mask]

print(f"Selected {U_cond.shape[0]} samples (~{100 * U_cond.shape[0] / n_samples:.2f}%) under stress scenario.")

# === Step 4: Invert PIT uniforms to real returns ===
columns = pseudo_obs_clean.columns
R_stress = np.column_stack([
    inverse_empirical(U_cond[:, i], sorted_returns[col])
    for i, col in enumerate(columns)
])

# === Step 5: Compute portfolio P&L under stress ===
P_stress = R_stress @ beta

# === Step 6: Risk metrics under stress ===
VaR_stress = np.quantile(P_stress, 1 - alpha)
ES_stress = P_stress[P_stress <= VaR_stress].mean()

print(f"\nConditioned on {cond_factor} ≈ {u_cond_val:.2f}:")
print(f"Unconditional VaR ({int(alpha*100)}%): {VaR_alpha:.4f}")
print(f"Conditional VaR ({int(alpha*100)}%): {VaR_stress:.4f}")
print(f"Unconditional ES ({int(alpha*100)}%): {ES_alpha:.4f}")
print(f"Conditional ES  ({int(alpha*100)}%): {ES_stress:.4f}")

# === Step 7: Plot comparison ===
plt.figure(figsize=(10, 5))
plt.hist(P_sim, bins=100, alpha=0.5, label="Unconditional", density=True)
plt.hist(P_stress, bins=100, alpha=0.5, label=f"Conditioned on {cond_factor} ≈ {u_cond_val:.2f}", density=True)
plt.axvline(VaR_alpha, color='blue', linestyle='--', label='Uncond VaR')
plt.axvline(ES_alpha, color='blue', linestyle=':', label='Uncond ES')
plt.axvline(VaR_stress, color='red', linestyle='--', label='Stress VaR')
plt.axvline(ES_stress, color='red', linestyle=':', label='Stress ES')
plt.title("Portfolio Return Distribution: Unconditional vs. Stress Scenario")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Selected 1025 samples (~1.02%) under stress scenario.
#
# Conditioned on HML_pure ≈ 0.05:
# Unconditional VaR (95%): -0.5560
# Conditional VaR (95%): -0.5189
# Unconditional ES (95%): -0.7964
# Conditional ES  (95%): -0.7855

# %%
import pandas as pd
import numpy as np
from arch import arch_model
from scipy.stats import t
import pyvinecopulib as pv
import matplotlib.pyplot as plt

# === Step 1: Load raw Fama-French data ===
df = pd.read_excel("Data_FF.xlsx", header=0, index_col=0)

# Use raw returns and convert % to decimals (they are usually in percent form)
returns = df / 100
# returns = returns.drop(columns=["RF"], errors='ignore')  # drop risk-free if present

# === Step 2: Compute pseudo-observations via GARCH ===
pseudo_obs = pd.DataFrame(index=returns.index)

for col in returns.columns:
    series = returns[col].dropna() * 1000
    if len(series) < 250:
        continue
    try:
        model = arch_model(series, vol='Garch', p=1, q=1, dist='StudentsT')
        res = model.fit(disp='off')
        std_resid = res.std_resid
        nu = res.params["nu"]
        u_t = pd.Series(t.cdf(std_resid, df=nu), index=std_resid.index)
        pseudo_obs[col] = u_t
    except Exception as e:
        print(f"GARCH failed on {col}: {e}")

# === Step 3: Fit vine copula ===
U = pseudo_obs.dropna().to_numpy(dtype=np.float64)
U = np.clip(U, 1e-6, 1 - 1e-6)
U = np.asfortranarray(U)

vine_ctrl = pv.FitControlsVinecop(
    family_set=[
        pv.BicopFamily.indep, pv.BicopFamily.gaussian, pv.BicopFamily.student,
        pv.BicopFamily.clayton, pv.BicopFamily.gumbel, pv.BicopFamily.frank
    ],
    parametric_method='itau',
    selection_criterion='bic'
)

vine = pv.Vinecop.from_data(data=U, controls=vine_ctrl)

# === Step 4: Simulate and invert ===
common_index = pseudo_obs.dropna().index.intersection(returns.dropna().index)
returns_clean = returns.loc[common_index]
pseudo_obs_clean = pseudo_obs.loc[common_index]

sorted_returns = {col: np.sort(returns_clean[col].values) for col in returns_clean.columns}

def inverse_empirical(u, sorted_vals):
    n = len(sorted_vals)
    ranks = u * (n - 1)
    lower_idx = np.floor(ranks).astype(int)
    upper_idx = np.ceil(ranks).astype(int)
    weights = ranks - lower_idx
    return (1 - weights) * sorted_vals[lower_idx] + weights * sorted_vals[upper_idx]

N = 100_000
U_sim = vine.simulate(n=N)
U_sim = np.clip(U_sim, 1e-6, 1 - 1e-6)

columns = pseudo_obs_clean.columns
R_sim = np.column_stack([
    inverse_empirical(U_sim[:, i], sorted_returns[col])
    for i, col in enumerate(columns)
])

# === Step 5: Portfolio P&L and risk metrics ===
beta = np.ones(len(columns)) / len(columns)
P_sim = R_sim @ beta

expected_return = np.mean(P_sim)
volatility = np.std(P_sim)
sharpe_ratio = expected_return / volatility
alpha = 0.95
VaR_alpha = np.quantile(P_sim, 1 - alpha)
ES_alpha = P_sim[P_sim <= VaR_alpha].mean()

portfolio_stats = {
    "Expected Return": expected_return,
    "Volatility": volatility,
    "Sharpe Ratio": sharpe_ratio,
    f"VaR {int(alpha*100)}%": VaR_alpha,
    f"ES {int(alpha*100)}%": ES_alpha
}

print(portfolio_stats)

# === Step 6: ES attribution ===
L_sim = -R_sim * beta
L_tail = L_sim[P_sim <= VaR_alpha]
ES_i = L_tail.mean(axis=0)
ES_total = ES_i.sum()

es_df = pd.DataFrame({
    "Weight (β)": beta,
    "ES Contribution": ES_i,
    "ES %": ES_i / ES_total * 100
}, index=columns)
es_df.loc["Total"] = ["", ES_total, 100.0]

es_df[:-1]["ES %"].plot(kind="bar", figsize=(12, 5), title="ES Contribution by Factor")
plt.ylabel("Percent of ES (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# === Step 7: Conditional scenario: e.g., HML at 5th percentile ===
cond_factor = "Mkt-RF"
u_cond_val = 0.05
bandwidth = 0.005
cond_col = list(columns).index(cond_factor)

mask = (U_sim[:, cond_col] >= u_cond_val - bandwidth) & (U_sim[:, cond_col] <= u_cond_val + bandwidth)
U_cond = U_sim[mask]

print(f"Selected {U_cond.shape[0]} samples (~{100 * U_cond.shape[0] / N:.2f}%) under stress scenario.")

R_stress = np.column_stack([
    inverse_empirical(U_cond[:, i], sorted_returns[col])
    for i, col in enumerate(columns)
])
P_stress = R_stress @ beta

VaR_stress = np.quantile(P_stress, 1 - alpha)
ES_stress = P_stress[P_stress <= VaR_stress].mean()

print(f"\nConditioned on {cond_factor} ≈ {u_cond_val:.2f}:")
print(f"Unconditional VaR ({int(alpha*100)}%): {VaR_alpha:.4f}")
print(f"Conditional VaR ({int(alpha*100)}%): {VaR_stress:.4f}")
print(f"Unconditional ES ({int(alpha*100)}%): {ES_alpha:.4f}")
print(f"Conditional ES  ({int(alpha*100)}%): {ES_stress:.4f}")

plt.figure(figsize=(10, 5))
plt.hist(P_sim, bins=100, alpha=0.5, label="Unconditional", density=True)
plt.hist(P_stress, bins=100, alpha=0.5, label=f"Conditioned on {cond_factor} ≈ {u_cond_val:.2f}", density=True)
plt.axvline(VaR_alpha, color='blue', linestyle='--', label='Uncond VaR')
plt.axvline(ES_alpha, color='blue', linestyle=':', label='Uncond ES')
plt.axvline(VaR_stress, color='red', linestyle='--', label='Stress VaR')
plt.axvline(ES_stress, color='red', linestyle=':', label='Stress ES')
plt.title("Portfolio Return Distribution: Unconditional vs. Stress Scenario")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\91843\Desktop\VineCopulas\.venv\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.01547. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# {'Expected Return': np.float64(0.00015133025271234736), 'Volatility': np.float64(0.001908446647858828), 'Sharpe Ratio': np.float64(0.0792949873040106), 'VaR 95%': np.float64(-0.0026499999999999996), 'ES 95%': np.float64(-0.0042603481410657335)}
# Selected 982 samples (~0.98%) under stress scenario.
#
# Conditioned on Mkt-RF ≈ 0.05:
# Unconditional VaR (95%): -0.0026
# Conditional VaR (95%): -0.0046
# Unconditional ES (95%): -0.0043
# Conditional ES  (95%): -0.0055
